# %%
import requests
res = requests.get('https://www.youtube.com/watch?v=B692I8fSAo8', verify = False)
print(res.text)
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:120: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# ...

# %%
import re
m = re.search('args":({.*?}),', res.text)
m.group(1)
# Out:
# u'{"ldpj":"-33","idpj":"-3","innertube_api_key":"AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8","length_seconds":"508","dashmpd":"https:\\/\\/manifest.googlevideo.com\\/api\\/manifest\\/dash\\/key\\/yt6\\/ip\\/210.61.122.2\\/as\\/fmp4_audio_clear%2Cwebm_audio_clear%2Cfmp4_sd_hd_clear%2Cwebm_sd_hd_clear%2Cwebm2_sd_hd_clear\\/source\\/youtube\\/upn\\/F749hWQxS1E\\/nh\\/IgpwcjAyLnRwZTA4KgkxMjcuMC4wLjE\\/signature\\/BA22D4790072502F61E2BEF13D65B4C515235F88.A312010CE586820524A43EC7467BB475904919EE\\/expire\\/1452694089\\/sver\\/3\\/playback_host\\/r15---sn-u2x76ne7.googlevideo.com\\/mn\\/sn-u2x76ne7\\/requiressl\\/yes\\/mv\\/m\\/mt\\/1452672353\\/ms\\/au\\/itag\\/0\\/sparams\\/as%2Chfr%2Cid%2Cip%2Cipbits%2Citag%2Cmm%2Cmn%2Cms%2Cmv%2Cnh%2Cpl%2Cplayback_host%2Crequiressl%2Csource%2Cexpire\\/fexp\\/9416126%2C9417368%2C9420452%2C9420718%2C9422541%2C9422542%2C9422596%2C9423606%2C9423662%2C9425701%2C9425744%2C9425838%2C9426139%2C9427016\\/id\\/o-AClCLgPNNSfPGkd09LyvHzee_hT95wDhE6BU8CKOLbmb\\/hfr\\/1\
# ...

# %%
import json
jd = json.loads(m.group(1))
print(jd['url_encoded_fmt_stream_map'])
# Out:
# fallback_host=tc.v2.cache3.googlevideo.com&url=https%3A%2F%2Fr15---sn-u2x76ne7.googlevideo.com%2Fvideoplayback%3Fkey%3Dyt6%26source%3Dyoutube%26upn%3DF749hWQxS1E%26nh%3DIgpwcjAyLnRwZTA4KgkxMjcuMC4wLjE%26signature%3D128CAAC6C5C34EF650F4908E33A107DD6920DF21.A7BFE4110FE89D922F02467FD203761A02F520FE%26ratebypass%3Dyes%26lmt%3D1427458387176524%26expire%3D1452694089%26sver%3D3%26mt%3D1452672353%26requiressl%3Dyes%26mime%3Dvideo%252Fmp4%26dur%3D507.564%26mv%3Dm%26ipbits%3D0%26ms%3Dau%26itag%3D22%26initcwndbps%3D15381250%26sparams%3Ddur%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv%252Cnh%252Cpl%252Cratebypass%252Crequiressl%252Csource%252Cupn%252Cexpire%26fexp%3D9416126%252C9417368%252C9420452%252C9420718%252C9422541%252C9422542%252C9422596%252C9423606%252C9423662%252C9425701%252C9425744%252C9425838%252C9426139%252C9427016%26id%3Do-AClCLgPNNSfPGkd09LyvHzee_hT95wDhE6BU8CKOLbmb%26mn%3Dsn-u2x76ne7%26mm%3D31%26ip%3D210.61.122.2%26pl%3D21&itag=22&
# ...

# %%
import urlparse
a = urlparse.parse_qs(jd['url_encoded_fmt_stream_map'])
a
# Out:
# {u'fallback_host': [u'tc.v2.cache3.googlevideo.com'],
#  u'itag': [u'22', u'43', u'18', u'5', u'36', u'17'],
#  u'quality': [u'hd720,fallback_host=tc.v17.cache8.googlevideo.com',
#   u'medium,fallback_host=tc.v1.cache4.googlevideo.com',
#   u'medium,fallback_host=tc.v24.cache5.googlevideo.com',
#   u'small,fallback_host=tc.v14.cache4.googlevideo.com',
#   u'small,fallback_host=tc.v22.cache5.googlevideo.com',
#   u'small'],
#  u'type': [u'video/mp4; codecs="avc1.64001F, mp4a.40.2"',
#   u'video/webm; codecs="vp8.0, vorbis"',
#   u'video/mp4; codecs="avc1.42001E, mp4a.40.2"',
#   u'video/x-flv',
#   u'video/3gpp; codecs="mp4v.20.3, mp4a.40.2"',
#   u'video/3gpp; codecs="mp4v.20.3, mp4a.40.2"'],
# ...

# %%
print a['url'][0]
# Out:
# https://r15---sn-u2x76ne7.googlevideo.com/videoplayback?key=yt6&source=youtube&upn=F749hWQxS1E&nh=IgpwcjAyLnRwZTA4KgkxMjcuMC4wLjE&signature=128CAAC6C5C34EF650F4908E33A107DD6920DF21.A7BFE4110FE89D922F02467FD203761A02F520FE&ratebypass=yes&lmt=1427458387176524&expire=1452694089&sver=3&mt=1452672353&requiressl=yes&mime=video%2Fmp4&dur=507.564&mv=m&ipbits=0&ms=au&itag=22&initcwndbps=15381250&sparams=dur%2Cid%2Cinitcwndbps%2Cip%2Cipbits%2Citag%2Clmt%2Cmime%2Cmm%2Cmn%2Cms%2Cmv%2Cnh%2Cpl%2Cratebypass%2Crequiressl%2Csource%2Cupn%2Cexpire&fexp=9416126%2C9417368%2C9420452%2C9420718%2C9422541%2C9422542%2C9422596%2C9423606%2C9423662%2C9425701%2C9425744%2C9425838%2C9426139%2C9427016&id=o-AClCLgPNNSfPGkd09LyvHzee_hT95wDhE6BU8CKOLbmb&mn=sn-u2x76ne7&mm=31&ip=210.61.122.2&pl=21

# %%
import shutil

res2 = requests.get(a['url'][0], verify = False, stream = True)
f = open('a.mp4', 'wb')
shutil.copyfileobj(res2.raw, f)
f.close()
# Out:
# C:\Python27\lib\site-packages\requests\packages\urllib3\util\ssl_.py:120: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
